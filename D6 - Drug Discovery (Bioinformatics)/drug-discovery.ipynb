# %% [markdown]
# # Computational Drug Discovery (Bioinformatics)

# %% [markdown]
# Building a Machine Learning Model using real-life ChEMBL bioactivity data.

# %% [markdown]
# ### ChEMBL Database

# %% [markdown]
# The [ChEMBL Database](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.

# %%
# Installing libraries
import sys
# !{sys.executable} -m pip install chembl_webresource_client

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ### Target Search

# %% [markdown]
# Target Search same as searching through the website manually for 'acetylcholinesterase'.

# %%
target = new_client.target
target_query = target.search('acetylcholinesterase')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                      cross_references  \
# 0   [{'xref_id': 'P22303', 'xref_name': None, 'xre...
# 1                                                  []
# 2                                                  []
# 3                                                  []
# 4   [{'xref_id': 'P04058', 'xref_name': None, 'xre...
# 5   [{'xref_id': 'P21836', 'xref_name': None, 'xre...
# 6   [{'xref_id': 'P37136', 'xref_name': None, 'xre...
# 7   [{'xref_id': 'O42275', 'xref_name': None, 'xre...
# 8   [{'xref_id': 'P23795', 'xref_name': None, 'xre...
# 9                                                  []
# 10                                                 []
# 11                                                 []
# 12                                                 []
# 13                                                 []
# 14  [{'xref_id': 'Q95P20', 'xref_name': None, 'xre...
# 15                                                 []
# ...

# %% [markdown]
# ## Select and retrieve bioactive data

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL220'

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id = selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)
df.head()
# Out:
#   activity_comment  activity_id activity_properties assay_chembl_id  \
# 0             None        33969                  []    CHEMBL643384
# 1             None        37563                  []    CHEMBL643384
# 2             None        37565                  []    CHEMBL643384
# 3             None        38902                  []    CHEMBL643384
# 4             None        41170                  []    CHEMBL643384
#
#                                    assay_description assay_type bao_endpoint  \
# 0  Inhibitory concentration against acetylcholine...          B  BAO_0000190
# 1  Inhibitory concentration against acetylcholine...          B  BAO_0000190
# 2  Inhibitory concentration against acetylcholine...          B  BAO_0000190
# 3  Inhibitory concentration against acetylcholine...          B  BAO_0000190
# 4  Inhibitory concentration against acetylcholine...          B  BAO_0000190
#
#     bao_format              bao_label  \
# 0  BAO_0000357  single protein format
# ...

# %% [markdown]
# Save the dataset into a **bioactivity_data.csv** file for convenience.

# %%
df.to_csv('bioactivity_data.csv', index=False)

# %% [markdown]
# Now that the file is safely saved, we can move on further to our EDA.

# %% [markdown]
# ### Handling Missing Data

# %% [markdown]
# If any compound is missing data for the standard_value column, it will be dropped.

# %%
df.shape
# Out:
# (7026, 43)

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#      activity_comment  activity_id activity_properties assay_chembl_id  \
# 0                None        33969                  []    CHEMBL643384
# 1                None        37563                  []    CHEMBL643384
# 2                None        37565                  []    CHEMBL643384
# 3                None        38902                  []    CHEMBL643384
# 4                None        41170                  []    CHEMBL643384
# ...               ...          ...                 ...             ...
# 7021             None     18798886                  []   CHEMBL4274263
# 7022             None     18798887                  []   CHEMBL4274263
# 7023             None     18798888                  []   CHEMBL4274263
# 7024             None     18798889                  []   CHEMBL4274263
# ...

# %%
len(df2.canonical_smiles.unique())
# Out:
# 4695

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#      activity_comment  activity_id activity_properties assay_chembl_id  \
# 0                None        33969                  []    CHEMBL643384
# 1                None        37563                  []    CHEMBL643384
# 2                None        37565                  []    CHEMBL643384
# 3                None        38902                  []    CHEMBL643384
# 4                None        41170                  []    CHEMBL643384
# ...               ...          ...                 ...             ...
# 7019             None     18798884                  []   CHEMBL4274263
# 7020             None     18798885                  []   CHEMBL4274263
# 7021             None     18798886                  []   CHEMBL4274263
# 7022             None     18798887                  []   CHEMBL4274263
# 7023             None     18798888                  []   CHEMBL4274263
#
#                                       assay_description assay_type  \
# ...

# %% [markdown]
# ## Data pre-processing of the bioactivity data

# %% [markdown]
# ### Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3.index = [i for i in range(len(df3.index))] #Getting indexes correct
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL133897              CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1
# 1          CHEMBL336398         O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1
# 2          CHEMBL131588  CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1
# 3          CHEMBL130628      O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F
# 4          CHEMBL130478          CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C
# ...                 ...                                                ...
# 4690      CHEMBL4293155  CC(C)(C)c1cc(/C=C/C(=O)NCCC2CCN(Cc3ccccc3Cl)CC...
# 4691      CHEMBL4282558  CC(C)(C)c1cc(/C=C/C(=O)NCCC2CCN(Cc3cccc(Cl)c3)...
# 4692      CHEMBL4281727  CC(C)(C)c1cc(/C=C/C(=O)NCCC2CCN(Cc3ccc(Br)cc3)...
# 4693      CHEMBL4292349  CC(C)(C)c1cc(/C=C/C(=O)NCCC2CCN(Cc3cccc([N+](=...
# 4694      CHEMBL4278260  CC(C)(C)c1cc(/C=C/C(=O)NCCC2CCN(Cc3ccc(C#N)cc3...
#
#      standard_value
# 0             750.0
# 1             100.0
# ...

# %% [markdown]
# ### Labeling compounds as active | inactive | intermediate

# %% [markdown]
# Compounds having values of less than 1000nM will be considered to be **active**, those greater than 10,000nM will be considered to be **inactive**. Values between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
bioactivity_threshold = []
for i in df3.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  elif float(i) < 10000 and float(i) > 1000:
    bioactivity_threshold.append("intermediate")
    
len(bioactivity_threshold)
# Out:
# 4695

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df3, bioactivity_class], axis=1, copy=False)
df5
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL133897              CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1
# 1          CHEMBL336398         O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1
# 2          CHEMBL131588  CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1
# 3          CHEMBL130628      O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F
# 4          CHEMBL130478          CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C
# ...                 ...                                                ...
# 4690      CHEMBL4293155  CC(C)(C)c1cc(/C=C/C(=O)NCCC2CCN(Cc3ccccc3Cl)CC...
# 4691      CHEMBL4282558  CC(C)(C)c1cc(/C=C/C(=O)NCCC2CCN(Cc3cccc(Cl)c3)...
# 4692      CHEMBL4281727  CC(C)(C)c1cc(/C=C/C(=O)NCCC2CCN(Cc3ccc(Br)cc3)...
# 4693      CHEMBL4292349  CC(C)(C)c1cc(/C=C/C(=O)NCCC2CCN(Cc3cccc([N+](=...
# 4694      CHEMBL4278260  CC(C)(C)c1cc(/C=C/C(=O)NCCC2CCN(Cc3ccc(C#N)cc3...
#
#      standard_value         class
# ...

# %% [markdown]
# Getting a separate df for molecule_chembl_id, canonical_smils, standard_value columns for removing redundancies in data.

# %%
df5.shape
# Out:
# (4695, 4)

# %%
df5.to_csv('bioactivity_preprocessed_data.csv', index=False)
